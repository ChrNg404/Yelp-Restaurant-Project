# %%
from yelpapi import YelpAPI
import json
import csv
import requests
import pandas as pd
from pprint import pprint
from yelp.client import Client
from config import apikey



#We're going to figure out the best category

#client = Client(MY_API_KEY)
#print(dir(client))
#print(help(client))

# %%
# Print each city's input into different lists. 
# We also need information on the restaurant's name, rating, and category
yelp_api = YelpAPI(apikey)
city_names = ["Oceanside", "Encinitas", "Carlsbad"]
data = {
    city: {
        'names': [],
        'ratings': [],
        'categories': []
    }
    for city in city_names
}

print(json.dumps(data, indent=4))
for city in city_names:
    search_results = yelp_api.search_query(location=city, term="restaurant", limit = 50, offset=100)
    # indent the next line if we're using the above loop
    # print(json.dumps(search_results, indent=4))
    # print([b['name'] for b in search_results['businesses']])
    for b in search_results['businesses']:
        #print([(b['name'],b['rating'])])
        data[city]['names'].append(b["name"])
        data[city]['ratings'].append(b["rating"])
        data[city]['categories'].append(b["categories"][0]['title']+"/"+b["categories"][0]["alias"])
        #data[city]['categories title'].append(b["categories"][0]["alias"])
        # Rating[city].append(b['rating'])
        # Category[city].append(b['categories'])
        #pprint([(b['name'],b['categories'])])
#print(category)
# print(len(search_results['businesses']))
# print(len(name))
# print(len(rating))
# print(len(category))
# print(len(city_list))
# THIS CODE PUTS EVERYTHING IN ONE LIST.
# NEED A WAY TO SEPERATE BASED ON CITY
pprint(data, indent=4)
# Out:
# {
#     "Oceanside": {
#         "names": [],
#         "ratings": [],
#         "categories": []
#     },
#     "Encinitas": {
#         "names": [],
#         "ratings": [],
#         "categories": []
#     },
#     "Carlsbad": {
#         "names": [],
#         "ratings": [],
#         "categories": []
#     }
# }
# {   'Carlsbad': {   'categories': [   'American (Traditional)/tradamerican',
#                                       'Gluten-Free/gluten_free',
#                                       'Gastropubs/gastropubs',
#                                       'American (New)/newamerican',
#                                       'Sushi Bars/sushi',
#                                       'Japanese/japanese',
#                                       'Greek/greek',
#                                       'Mexican/mexican',
#                                       'Tacos/tacos',
#                                       'Gastropubs/gastropubs',
#                                       'Italian/italian',
#                                       'American (New)/newamerican',
#                                       'Cafes/cafes',
#                                       'Persian/Iranian/persian',
#                                       'Vietnamese/vietnamese',
#                                       'Pizza/pizza',
#                                       'Burgers/burgers',
#                                       'Coffee & Tea/coffee',
#                                       'American (Traditional)/tradamerican',
#                                       'Breweries/breweries',
#                                       'Vietnamese/vietnamese',
#                                       'French/french',
#                                       'Seafood/seafood',
#                                       'Pizza/pizza',
#                                       'Filipino/filipino',
#                                       'Mexican/mexican',
#                                       'American (New)/newamerican',
#                                       'Mediterranean/mediterranean',
#                                       'Seafood/seafood',
#                                       'Fast Food/hotdogs',
#                                       'Bars/bars',
#                                       'Mexican/mexican',
#                                       'Barbeque/bbq',
#                                       'American (Traditional)/tradamerican',
#                                       'Noodles/noodles',
#                                       'Coffee & Tea/coffee',
#                                       'Wine Bars/wine_bars',
#                                       'Seafood/seafood',
#                                       'Japanese/japanese',
#                                       'Ramen/ramen',
#                                       'Vegan/vegan',
#                                       'Thai/thai',
#                                       'Pizza/pizza',
#                                       'Italian/italian',
#                                       'Filipino/filipino',
#                                       'Burgers/burgers',
#                                       'American (New)/newamerican',
#                                       'Vietnamese/vietnamese',
#                                       'Hawaiian/hawaiian',
#                                       'Italian/italian'],
#                     'names': [   "Landon's Gourmet Kitchen",
#                                  'Naked Cafe',
#                                  'Urge Gastropub and Whiskey Bank',
#                                  '20|Twenty',
#                                  'Kai Ola Sushi',
#                                  'Maru Restaurant',
#                                  'Greek Corner Cafe North County',
#                                  "Rockin' Baja Lobster",
#                                  'Lucha Libre Gourmet Taco Shop',
#                                  'Priority Public House',
#                                  "Fratelli's Italian Kitchen",
#                                  'Wrench & Rodent Seabasstropub',
#                                  'The Story Caffe',
#                                  'Kabob Lounge',
#                                  'Pho Guys',
#                                  'Pizza Port Bressi Ranch',
#                                  'Notorious Burgers',
#                                  'Succulent Cafe',
#                                  'The Crack Shack',
#                                  "BJ's Restaurant & Brewhouse",
#                                  'Birdseye Kitchen',
#                                  'French Corner at The Island',
#                                  'Cancun Mexican and Seafood',
#                                  'Knockout Pizza',
#                                  'CARiN de RiA',
#                                  'Las Olas',
#                                  'Stone Brewing World Bistro & Gardens '
#                                  'Escondido',
#                                  'Ara Lebanese Grill',
#                                  'Lobster West',
#                                  'In-N-Out Burger',
#                                  '508 Tavern',
#                                  'Norte Mexican Food & Cocktail',
#                                  'Guahan Grill',
#                                  'Village Kitchen & Pie Shoppe',
#                                  'Noodles & Company',
#                                  'Vinaka Cafe',
#                                  'Solterra Winery & Kitchen',
#                                  'Brigantine',
#                                  'Umami Japanese',
#                                  'Wulan Ramen Tap House',
#                                  'Happy Pantry',
#                                  "Onny's Thai Restaurant",
#                                  'Rosaria Pizza',
#                                  'Buca di Beppo Italian Restaurant',
#                                  'Lutchi and Mary',
#                                  'Islands Restaurant',
#                                  'Vue',
#                                  'Pho House & Grill',
#                                  'Homestyle Hawaiian',
#                                  'Pizza & Pasta Buffet'],
#                     'ratings': [   4.5,
#                                    4.0,
#                                    4.0,
#                                    3.5,
#                                    4.5,
#                                    4.0,
#                                    4.0,
#                                    4.0,
#                                    3.5,
#                                    4.0,
#                                    4.5,
#                                    4.5,
#                                    4.5,
#                                    3.5,
#                                    5.0,
#                                    3.5,
#                                    3.5,
#                                    4.5,
#                                    4.0,
#                                    3.0,
#                                    4.0,
#                                    4.5,
#                                    4.5,
#                                    4.0,
#                                    4.5,
#                                    3.5,
#                                    4.0,
#                                    4.5,
#                                    4.0,
#                                    4.5,
#                                    4.5,
#                                    3.0,
#                                    4.5,
#                                    4.0,
#                                    3.5,
#                                    4.0,
#                                    4.0,
#                                    4.0,
#                                    4.5,
#                                    4.0,
#                                    5.0,
#                                    4.0,
#                                    5.0,
#                                    3.0,
#                                    5.0,
#                                    3.5,
#                                    4.0,
#                                    3.5,
#                                    4.0,
#                                    4.0]},
#     'Encinitas': {   'categories': [   'Pubs/pubs',
#                                        'Fast Food/hotdogs',
#                                        'Ramen/ramen',
#                                        'Mexican/mexican',
#                                        'Breweries/breweries',
#                                        'Italian/italian',
#                                        'Salad/salad',
#                                        'Pizza/pizza',
#                                        'Chinese/chinese',
#                                        'Vegetarian/vegetarian',
#                                        'American (Traditional)/tradamerican',
#                                        'Italian/italian',
#                                        'Peruvian/peruvian',
#                                        'Mediterranean/mediterranean',
#                                        'Burgers/burgers',
#                                        'Seafood/seafood',
#                                        'American (New)/newamerican',
#                                        'Steakhouses/steak',
#                                        'American (Traditional)/tradamerican',
#                                        'Pubs/pubs',
#                                        'Gastropubs/gastropubs',
#                                        'Burgers/burgers',
#                                        'Sushi Bars/sushi',
#                                        'Comfort Food/comfortfood',
#                                        'Vietnamese/vietnamese',
#                                        'Sandwiches/sandwiches',
#                                        'Steakhouses/steak',
#                                        'Pizza/pizza',
#                                        'Southern/southern',
#                                        'Acai Bowls/acaibowls',
#                                        'Bars/bars',
#                                        'Indian/indpak',
#                                        'Burgers/burgers',
#                                        'Thai/thai',
#                                        'Korean/korean',
#                                        'American (New)/newamerican',
#                                        'Mexican/mexican',
#                                        'Mexican/mexican',
#                                        'Sushi Bars/sushi',
#                                        'Mexican/mexican',
#                                        'American (Traditional)/tradamerican',
#                                        'Italian/italian',
#                                        'Italian/italian',
#                                        'Pizza/pizza',
#                                        'Seafood/seafood',
#                                        'American (New)/newamerican',
#                                        'Japanese/japanese',
#                                        'Latin American/latin',
#                                        'Wine Bars/wine_bars',
#                                        'American (New)/newamerican'],
#                      'names': [   'Flying Pig Pub & Kitchen',
#                                   'Grabbagreen',
#                                   'Ramen Factory',
#                                   'Casa de Bandini',
#                                   'Ballast Point Scripps Ranch',
#                                   'Leucadia Pizzeria & Italian Restaurant',
#                                   'The Craftsman New American Tavern',
#                                   'Napizza',
#                                   'Chinatown Restaurant',
#                                   'Lotus Cafe & Juice Bar',
#                                   'Lumberyard Tavern & Grill',
#                                   "Rosanna's Pasta Shop",
#                                   'Pisco Rotisserie & Cevicheria',
#                                   'Ara Lebanese Grill',
#                                   'Bushfire Kitchen - La Costa',
#                                   'Chart House',
#                                   'Ignite Bistro & Wine Spot',
#                                   'West Steak and Seafood',
#                                   'The Encinitas Cafe',
#                                   'Karl Strauss Brewing Company',
#                                   'The Compass',
#                                   'Islands Restaurant',
#                                   'HapiFish',
#                                   'Draft Republic Carlsbad',
#                                   'Pho Kitchen',
#                                   'The Sandwich Spot',
#                                   'Texas Roadhouse',
#                                   'Pizzaiolo',
#                                   "Felix's BBQ With Soul",
#                                   'Everbowl',
#                                   "Mr. Peabody's Bar & Grill Live Music",
#                                   'Passage to India',
#                                   'In-N-Out Burger',
#                                   'Similan Thai Restaurant',
#                                   'Manna Korean BBQ',
#                                   'Prep Kitchen - San Marcos',
#                                   'Lourdes',
#                                   'El Nopalito',
#                                   'Sushi Brothers',
#                                   'Las Olas Mexican Restaurant',
#                                   'The Cork and Craft',
#                                   'Mangia e Bevi',
#                                   'Trattoria Positano',
#                                   'Pie Craft',
#                                   'Fish House-Solana Beach',
#                                   'Stone Brewing World Bistro & Gardens '
#                                   'Escondido',
#                                   'Umami Japanese',
#                                   'Death by Tequila',
#                                   'Oak + Elixir',
#                                   'Prep Kitchen - Del Mar'],
#                      'ratings': [   4.5,
#                                     4.0,
#                                     3.5,
#                                     4.0,
#                                     4.5,
#                                     3.5,
#                                     3.5,
#                                     4.0,
#                                     4.0,
#                                     4.0,
#                                     3.5,
#                                     4.0,
#                                     4.0,
#                                     4.5,
#                                     4.0,
#                                     3.0,
#                                     4.0,
#                                     4.5,
#                                     4.0,
#                                     4.0,
#                                     4.0,
#                                     3.5,
#                                     3.5,
#                                     4.0,
#                                     5.0,
#                                     4.0,
#                                     4.0,
#                                     4.0,
#                                     4.5,
#                                     4.5,
#                                     4.0,
#                                     3.5,
#                                     4.5,
#                                     4.0,
#                                     4.0,
#                                     4.0,
#                                     4.0,
#                                     4.0,
#                                     4.0,
#                                     3.5,
#                                     4.0,
#                                     5.0,
#                                     4.0,
#                                     4.0,
#                                     4.0,
#                                     4.0,
#                                     4.5,
#                                     3.5,
#                                     4.5,
#                                     4.0]},
#     'Oceanside': {   'categories': [   'Barbeque/bbq',
#                                        'Seafood/seafood',
#                                        'Creperies/creperies',
#                                        'Burgers/burgers',
#                                        'Chinese/chinese',
#                                        'Diners/diners',
#                                        'Salad/salad',
#                                        'Japanese/japanese',
#                                        'Japanese/japanese',
#                                        'Vietnamese/vietnamese',
#                                        'Gastropubs/gastropubs',
#                                        'Seafood/seafood',
#                                        'Italian/italian',
#                                        'Fast Food/hotdogs',
#                                        'Italian/italian',
#                                        'Persian/Iranian/persian',
#                                        'Pizza/pizza',
#                                        'Pizza/pizza',
#                                        'Pizza/pizza',
#                                        'American (New)/newamerican',
#                                        'American (New)/newamerican',
#                                        'Wine Bars/wine_bars',
#                                        'Mediterranean/mediterranean',
#                                        'Thai/thai',
#                                        'Breweries/breweries',
#                                        'Thai/thai',
#                                        'Buffets/buffets',
#                                        'Noodles/noodles',
#                                        'Korean/korean',
#                                        'Sushi Bars/sushi',
#                                        'Mexican/mexican',
#                                        'Thai/thai',
#                                        'Barbeque/bbq',
#                                        'Vietnamese/vietnamese',
#                                        'Donuts/donuts',
#                                        'Barbeque/bbq',
#                                        'Delis/delis',
#                                        'Mexican/mexican',
#                                        'Mexican/mexican',
#                                        'Burgers/burgers',
#                                        'Pizza/pizza',
#                                        'Pizza/pizza',
#                                        'American (Traditional)/tradamerican',
#                                        'Wine Bars/wine_bars',
#                                        'Mexican/mexican',
#                                        'Pizza/pizza',
#                                        'Pizza/pizza',
#                                        'Grocery/grocery',
#                                        'Comfort Food/comfortfood',
#                                        'Greek/greek'],
#                      'names': [   'That Boy Good',
#                                   'Lighthouse Oyster Bar & Grill',
#                                   "Elena's Cafe French Crepes",
#                                   'PCH Sports Bar & Grill',
#                                   "Chin's Szechwan Cuisine - Oceanside",
#                                   'Pit Stop Diner',
#                                   'ZIGZAG Pizza',
#                                   'Love Boat Sushi',
#                                   'Sunshine Poke & Sushi Rolls',
#                                   'Pho Guys',
#                                   'Flying Pig Pub & Kitchen - Vista',
#                                   'Fish 101',
#                                   "Vigilucci's Seafood & Steakhouse",
#                                   "Raising Cane's",
#                                   'Ciao Ristorante Italiano',
#                                   'Grill House Cafe San Marcos',
#                                   'Killer Pizza From Mars',
#                                   'Pizzamaniac',
#                                   "Benito's Cafe",
#                                   'Yard House',
#                                   'WildWood Crossing',
#                                   'Partake Gastropub',
#                                   'Luna Grill Carlsbad - El Camino Real',
#                                   'Ocean Thai Cuisine',
#                                   'Breakwater Brewing Company',
#                                   'BKK Thai Kitchen',
#                                   'Luxe Buffet',
#                                   'Noodles & Company',
#                                   'M. BBQ',
#                                   'Rising Sun Sushi Harbor',
#                                   "Marieta's Fine Mexican Food & Cocktails",
#                                   'Thai Thai Restaurant',
#                                   "Phil's BBQ",
#                                   'Yummy Pho',
#                                   'Doughside Donuts',
#                                   'L&L Hawaiian Barbecue',
#                                   'Beach Hut Deli',
#                                   'San Luis Mexican Food',
#                                   "Anita's Mexican Restaurant And Cantina",
#                                   'The Habit Burger Grill',
#                                   'Brooklyn Boyz Pizza',
#                                   "Carmine's",
#                                   'Start Fresh Cafe',
#                                   'Paon Restaurant and Wine Bar',
#                                   'Mariscos Ensenada',
#                                   'Venetos',
#                                   'Buona Forchetta',
#                                   'Mission Asian Market',
#                                   'Draft Republic Carlsbad',
#                                   'Greek Corner Cafe North County'],
#                      'ratings': [   4.0,
#                                     3.5,
#                                     5.0,
#                                     4.5,
#                                     4.0,
#                                     4.0,
#                                     4.0,
#                                     4.0,
#                                     4.5,
#                                     5.0,
#                                     4.0,
#                                     4.5,
#                                     4.0,
#                                     3.5,
#                                     4.5,
#                                     5.0,
#                                     4.0,
#                                     5.0,
#                                     4.5,
#                                     4.0,
#                                     4.0,
#                                     4.5,
#                                     4.0,
#                                     4.0,
#                                     4.0,
#                                     4.0,
#                                     3.5,
#                                     3.5,
#                                     3.5,
#                                     4.5,
#                                     4.0,
#                                     4.5,
#                                     4.0,
#                                     4.0,
#                                     5.0,
#                                     4.0,
#                                     4.5,
#                                     4.5,
#                                     3.5,
#                                     4.0,
#                                     4.0,
#                                     4.0,
#                                     4.5,
#                                     4.5,
#                                     4.0,
#                                     3.5,
#                                     5.0,
#                                     4.0,
#                                     4.0,
#                                     4.0]}}

# %%
data = dict()
cities = ["San Diego","Carlsbad","Encinitas"]
for index, city in enumerate(cities):
    data[city] = []
    print(city)
    data[city].append(index)
    
print(data)
# Out:
# San Diego
# Carlsbad
# Encinitas
# {'San Diego': [0], 'Carlsbad': [1], 'Encinitas': [2]}

# %%
# Now that we have everything in seperate lists, let's put it together into a dataframe
Oceanside_df = pd.DataFrame.from_dict(data["Oceanside"])
Carlsbad_df = pd.DataFrame.from_dict(data["Carlsbad"])
Encinitas_df = pd.DataFrame.from_dict(data["Encinitas"])

Encinitas_df.head(15)
# Out:
#                                      names  ratings  \
# 0                 Flying Pig Pub & Kitchen      4.5
# 1                              Grabbagreen      4.0
# 2                            Ramen Factory      3.5
# 3                          Casa de Bandini      4.0
# 4              Ballast Point Scripps Ranch      4.5
# 5   Leucadia Pizzeria & Italian Restaurant      3.5
# 6        The Craftsman New American Tavern      3.5
# 7                                  Napizza      4.0
# 8                     Chinatown Restaurant      4.0
# 9                   Lotus Cafe & Juice Bar      4.0
# 10               Lumberyard Tavern & Grill      3.5
# 11                    Rosanna's Pasta Shop      4.0
# 12           Pisco Rotisserie & Cevicheria      4.0
# 13                      Ara Lebanese Grill      4.5
# 14             Bushfire Kitchen - La Costa      4.0
#
#                              categories
# 0                             Pubs/pubs
# 1                     Fast Food/hotdogs
# 2                           Ramen/ramen
# 3                       Mexican/mexican
# 4                   Breweries/breweries
# 5                       Italian/italian
# 6                           Salad/salad
# 7                           Pizza/pizza
# 8                       Chinese/chinese
# 9                 Vegetarian/vegetarian
# 10  American (Traditional)/tradamerican
# 11                      Italian/italian
# 12                    Peruvian/peruvian
# 13          Mediterranean/mediterranean
# 14                      Burgers/burgers

# %%
# Once everything is in a dataframe, we can start plotting it.
# I recommend doing groupbys first.
# We'll be doing graphs based primarily on cities, so let's start there

# %%
# Next we need graphs based on ratings. So let's do some ratings groupbys.

# %%
# Finally, we need data based on categories.
