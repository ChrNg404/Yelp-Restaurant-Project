# %%
# Dependencies
import os
import glob
import numpy as np
import pandas as pd
import requests
import json
import matplotlib.pyplot as plt
from pprint import pprint

# %%
#to get the different categories from categories.json in Resources

restaurant_categories = []

with open('Resources/categories.json') as json_file:
    cats = json.load(json_file)
    
    for category in cats:
        try:
            if category['parents'][0]=='restaurants':
                restaurant_categories.append(category['alias'])
            
        except Exception as e:
            #print(f'Restaurant not found. Skipping...')
            pass  # no operation

print(len(restaurant_categories))
# Out:
# 190

# %%
cities = ["Carlsbad,CA", "Encinitas,CA", "Oceanside,CA", "San Marcos,CA"]
name_list = []
category_list = []
rating_list = []
review_count_list = []
price_list = []
total_count_dict = {
    "Oceanside,CA": [],
    "Encinitas,CA":[],
    "Carlsbad,CA":[],
    "San Marcos,CA": []
}

city_list = []

for city in cities:
    print(city)
    
    for category in restaurant_categories:
      
        filename = f"Resources/{city}/{category}.json"
        #print(filename)
        with open(filename) as json_file:
            restaurants_json = json.load(json_file)
            total_count_dict[city].append(restaurants_json['total'])
            
            for restaurant in restaurants_json['businesses']:
                try:
                    city_list.append(city)
                    name_list.append(restaurant['name'])

                    category_list.append(category) 

                    review_count_list.append(restaurant['review_count'])
                    rating_list.append(restaurant['rating'])

                    #if restaurant does not have a restaurant['price'] value, provide a value (but how?)
                    #https://stackoverflow.com/questions/24898797/check-if-key-exists-and-iterate-the-json-array-using-python
                    if 'price' not in restaurant:
                        price_list.append("0")
                    else:
                        price_list.append(len(restaurant['price']))
                except Exception as e:
                    print (e)

print(len(total_count_dict['Oceanside,CA']))                  
print(len(name_list))
print(len(category_list))
print(len(review_count_list))
print(len(rating_list))
print(len(price_list))
# Out:
# Carlsbad,CA
# Resources/Carlsbad,CA/afghani.json
# Resources/Carlsbad,CA/african.json
# Resources/Carlsbad,CA/andalusian.json
# Resources/Carlsbad,CA/arabian.json
# Resources/Carlsbad,CA/argentine.json
# Resources/Carlsbad,CA/armenian.json
# Resources/Carlsbad,CA/asianfusion.json
# Resources/Carlsbad,CA/asturian.json
# Resources/Carlsbad,CA/australian.json
# Resources/Carlsbad,CA/austrian.json
# Resources/Carlsbad,CA/baguettes.json
# Resources/Carlsbad,CA/bangladeshi.json
# Resources/Carlsbad,CA/basque.json
# Resources/Carlsbad,CA/bavarian.json
# Resources/Carlsbad,CA/bbq.json
# Resources/Carlsbad,CA/beergarden.json
# Resources/Carlsbad,CA/beerhall.json
# Resources/Carlsbad,CA/beisl.json
# Resources/Carlsbad,CA/belgian.json
# Resources/Carlsbad,CA/bistros.json
# Resources/Carlsbad,CA/blacksea.json
# Resources/Carlsbad,CA/brasseries.json
# Resources/Carlsbad,CA/brazilian.json
# Resources/Carlsbad,CA/breakfast_brunch.json
# Resources/Carlsbad,CA/british.json
# Resources/Carlsbad,CA/buffets.json
# Resources/Carlsbad,CA/bulgarian.json
# Resources/Carlsbad,CA/burgers.json
# Resources/Carlsbad,CA/burmese.json
# Resources/Carlsbad,CA/cafes.json
# Resources/Carlsbad,CA/cafeteria.json
# Resources/Carlsbad,CA/cajun.json
# Resources/Carlsbad,CA/cambodian.json
# Resources/Carlsbad,CA/canteen.json
# Resources/Carlsbad,CA/caribbean.json
# Resources/Carlsbad,CA/catalan.json
# Resources/Carlsbad,CA/cheesesteaks.json
# Resources/Carlsbad,CA/chicken_wings.json
# Resources/Carlsbad,CA/chickenshop.json
# Resources/Carlsbad,CA/chilean.json
# Resources/Carlsbad,CA/chinese.json
# Resources/Carlsbad,CA/comfortfood.json
# Resources/Carlsbad,CA/corsican.json
# Resources/Carlsbad,CA/creperies.json
# Resources/Carlsbad,CA/cuban.json
# Resources/Carlsbad,CA/currysausage.json
# Resources/Carlsbad,CA/cypriot.json
# Resources/Carlsbad,CA/czech.json
# Resources/Carlsbad,CA/czechslovakian.json
# Resources/Carlsbad,CA/danish.json
# Resources/Carlsbad,CA/delis.json
# Resources/Carlsbad,CA/diners.json
# Resources/Carlsbad,CA/dinnertheater.json
# Resources/Carlsbad,CA/dumplings.json
# Resources/Carlsbad,CA/eastern_european.json
# Resources/Carlsbad,CA/eltern_cafes.json
# Resources/Carlsbad,CA/ethiopian.json
# Resources/Carlsbad,CA/filipino.json
# Resources/Carlsbad,CA/fischbroetchen.json
# Resources/Carlsbad,CA/fishnchips.json
# Resources/Carlsbad,CA/flatbread.json
# Resources/Carlsbad,CA/fondue.json
# Resources/Carlsbad,CA/food_court.json
# Resources/Carlsbad,CA/foodstands.json
# Resources/Carlsbad,CA/freiduria.json
# Resources/Carlsbad,CA/french.json
# Resources/Carlsbad,CA/galician.json
# Resources/Carlsbad,CA/gamemeat.json
# Resources/Carlsbad,CA/gastropubs.json
# Resources/Carlsbad,CA/georgian.json
# Resources/Carlsbad,CA/german.json
# Resources/Carlsbad,CA/giblets.json
# Resources/Carlsbad,CA/gluten_free.json
# Resources/Carlsbad,CA/greek.json
# Resources/Carlsbad,CA/guamanian.json
# Resources/Carlsbad,CA/halal.json
# Resources/Carlsbad,CA/hawaiian.json
# Resources/Carlsbad,CA/heuriger.json
# Resources/Carlsbad,CA/himalayan.json
# Resources/Carlsbad,CA/hkcafe.json
# Resources/Carlsbad,CA/honduran.json
# Resources/Carlsbad,CA/hotdog.json
# Resources/Carlsbad,CA/hotdogs.json
# Resources/Carlsbad,CA/hotpot.json
# Resources/Carlsbad,CA/hungarian.json
# Resources/Carlsbad,CA/iberian.json
# Resources/Carlsbad,CA/indonesian.json
# Resources/Carlsbad,CA/indpak.json
# Resources/Carlsbad,CA/international.json
# Resources/Carlsbad,CA/irish.json
# Resources/Carlsbad,CA/island_pub.json
# Resources/Carlsbad,CA/israeli.json
# Resources/Carlsbad,CA/italian.json
# Resources/Carlsbad,CA/japanese.json
# Resources/Carlsbad,CA/jewish.json
# Resources/Carlsbad,CA/kebab.json
# Resources/Carlsbad,CA/kopitiam.json
# Resources/Carlsbad,CA/korean.json
# Resources/Carlsbad,CA/kosher.json
# Resources/Carlsbad,CA/kurdish.json
# Resources/Carlsbad,CA/laos.json
# Resources/Carlsbad,CA/laotian.json
# Resources/Carlsbad,CA/latin.json
# Resources/Carlsbad,CA/lyonnais.json
# Resources/Carlsbad,CA/malaysian.json
# Resources/Carlsbad,CA/meatballs.json
# Resources/Carlsbad,CA/mediterranean.json
# Resources/Carlsbad,CA/mexican.json
# Resources/Carlsbad,CA/mideastern.json
# Resources/Carlsbad,CA/milkbars.json
# Resources/Carlsbad,CA/modern_australian.json
# Resources/Carlsbad,CA/modern_european.json
# Resources/Carlsbad,CA/mongolian.json
# Resources/Carlsbad,CA/moroccan.json
# Resources/Carlsbad,CA/newamerican.json
# Resources/Carlsbad,CA/newcanadian.json
# Resources/Carlsbad,CA/newmexican.json
# Resources/Carlsbad,CA/newzealand.json
# Resources/Carlsbad,CA/nicaraguan.json
# Resources/Carlsbad,CA/nightfood.json
# Resources/Carlsbad,CA/nikkei.json
# Resources/Carlsbad,CA/noodles.json
# Resources/Carlsbad,CA/norcinerie.json
# Resources/Carlsbad,CA/norwegian.json
# Resources/Carlsbad,CA/opensandwiches.json
# Resources/Carlsbad,CA/oriental.json
# Resources/Carlsbad,CA/pakistani.json
# Resources/Carlsbad,CA/panasian.json
# Resources/Carlsbad,CA/parma.json
# Resources/Carlsbad,CA/persian.json
# Resources/Carlsbad,CA/peruvian.json
# Resources/Carlsbad,CA/pfcomercial.json
# Resources/Carlsbad,CA/pita.json
# Resources/Carlsbad,CA/pizza.json
# Resources/Carlsbad,CA/polish.json
# Resources/Carlsbad,CA/polynesian.json
# Resources/Carlsbad,CA/popuprestaurants.json
# Resources/Carlsbad,CA/portuguese.json
# Resources/Carlsbad,CA/potatoes.json
# Resources/Carlsbad,CA/poutineries.json
# Resources/Carlsbad,CA/pubfood.json
# Resources/Carlsbad,CA/raw_food.json
# Resources/Carlsbad,CA/riceshop.json
# Resources/Carlsbad,CA/romanian.json
# Resources/Carlsbad,CA/rotisserie_chicken.json
# Resources/Carlsbad,CA/russian.json
# Resources/Carlsbad,CA/salad.json
# Resources/Carlsbad,CA/sandwiches.json
# Resources/Carlsbad,CA/scandinavian.json
# Resources/Carlsbad,CA/schnitzel.json
# Resources/Carlsbad,CA/scottish.json
# Resources/Carlsbad,CA/seafood.json
# Resources/Carlsbad,CA/serbocroatian.json
# Resources/Carlsbad,CA/signature_cuisine.json
# Resources/Carlsbad,CA/singaporean.json
# Resources/Carlsbad,CA/slovakian.json
# Resources/Carlsbad,CA/soulfood.json
# Resources/Carlsbad,CA/soup.json
# Resources/Carlsbad,CA/southern.json
# Resources/Carlsbad,CA/spanish.json
# Resources/Carlsbad,CA/srilankan.json
# Resources/Carlsbad,CA/steak.json
# Resources/Carlsbad,CA/sud_ouest.json
# Resources/Carlsbad,CA/supperclubs.json
# Resources/Carlsbad,CA/sushi.json
# Resources/Carlsbad,CA/swabian.json
# Resources/Carlsbad,CA/swedish.json
# Resources/Carlsbad,CA/swissfood.json
# Resources/Carlsbad,CA/syrian.json
# Resources/Carlsbad,CA/tabernas.json
# Resources/Carlsbad,CA/taiwanese.json
# Resources/Carlsbad,CA/tapas.json
# Resources/Carlsbad,CA/tapasmallplates.json
# Resources/Carlsbad,CA/tavolacalda.json
# Resources/Carlsbad,CA/tex-mex.json
# Resources/Carlsbad,CA/thai.json
# Resources/Carlsbad,CA/tradamerican.json
# Resources/Carlsbad,CA/traditional_swedish.json
# Resources/Carlsbad,CA/trattorie.json
# Resources/Carlsbad,CA/turkish.json
# Resources/Carlsbad,CA/ukrainian.json
# Resources/Carlsbad,CA/uzbek.json
# Resources/Carlsbad,CA/vegan.json
# Resources/Carlsbad,CA/vegetarian.json
# Resources/Carlsbad,CA/venison.json
# Resources/Carlsbad,CA/vietnamese.json
# Resources/Carlsbad,CA/waffles.json
# Resources/Carlsbad,CA/wok.json
# Resources/Carlsbad,CA/wraps.json
# Resources/Carlsbad,CA/yugoslav.json
# Encinitas,CA
# Resources/Encinitas,CA/afghani.json
# Resources/Encinitas,CA/african.json
# Resources/Encinitas,CA/andalusian.json
# Resources/Encinitas,CA/arabian.json
# Resources/Encinitas,CA/argentine.json
# Resources/Encinitas,CA/armenian.json
# Resources/Encinitas,CA/asianfusion.json
# Resources/Encinitas,CA/asturian.json
# Resources/Encinitas,CA/australian.json
# Resources/Encinitas,CA/austrian.json
# Resources/Encinitas,CA/baguettes.json
# Resources/Encinitas,CA/bangladeshi.json
# Resources/Encinitas,CA/basque.json
# Resources/Encinitas,CA/bavarian.json
# Resources/Encinitas,CA/bbq.json
# Resources/Encinitas,CA/beergarden.json
# Resources/Encinitas,CA/beerhall.json
# Resources/Encinitas,CA/beisl.json
# Resources/Encinitas,CA/belgian.json
# Resources/Encinitas,CA/bistros.json
# Resources/Encinitas,CA/blacksea.json
# Resources/Encinitas,CA/brasseries.json
# Resources/Encinitas,CA/brazilian.json
# Resources/Encinitas,CA/breakfast_brunch.json
# Resources/Encinitas,CA/british.json
# Resources/Encinitas,CA/buffets.json
# Resources/Encinitas,CA/bulgarian.json
# Resources/Encinitas,CA/burgers.json
# Resources/Encinitas,CA/burmese.json
# Resources/Encinitas,CA/cafes.json
# Resources/Encinitas,CA/cafeteria.json
# Resources/Encinitas,CA/cajun.json
# Resources/Encinitas,CA/cambodian.json
# Resources/Encinitas,CA/canteen.json
# Resources/Encinitas,CA/caribbean.json
# Resources/Encinitas,CA/catalan.json
# Resources/Encinitas,CA/cheesesteaks.json
# Resources/Encinitas,CA/chicken_wings.json
# Resources/Encinitas,CA/chickenshop.json
# Resources/Encinitas,CA/chilean.json
# Resources/Encinitas,CA/chinese.json
# Resources/Encinitas,CA/comfortfood.json
# Resources/Encinitas,CA/corsican.json
# Resources/Encinitas,CA/creperies.json
# Resources/Encinitas,CA/cuban.json
# Resources/Encinitas,CA/currysausage.json
# Resources/Encinitas,CA/cypriot.json
# Resources/Encinitas,CA/czech.json
# Resources/Encinitas,CA/czechslovakian.json
# Resources/Encinitas,CA/danish.json
# Resources/San Marcos,CA/tex-mex.json
# Resources/San Marcos,CA/thai.json
# Resources/San Marcos,CA/tradamerican.json
# Resources/San Marcos,CA/traditional_swedish.json
# Resources/San Marcos,CA/trattorie.json
# Resources/San Marcos,CA/turkish.json
# Resources/San Marcos,CA/ukrainian.json
# Resources/San Marcos,CA/uzbek.json
# Resources/San Marcos,CA/vegan.json
# Resources/San Marcos,CA/vegetarian.json
# Resources/San Marcos,CA/venison.json
# Resources/San Marcos,CA/vietnamese.json
# Resources/San Marcos,CA/waffles.json
# Resources/San Marcos,CA/wok.json
# Resources/San Marcos,CA/wraps.json
# Resources/San Marcos,CA/yugoslav.json
# 190
# 9307
# 9307
# 9307
# 9307
# 9307

# %%
#Total Restaurant Count per Category
total_restaurant_df = pd.DataFrame(total_count_dict)
total_restaurant_df['Category'] = restaurant_categories
total_restaurant_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b0c12732a446> in <module>()
#       1 #Total Restaurant Count per Category
#       2 total_restaurant_df = pd.DataFrame(total_count_dict)
# ----> 3 total_restaurant_df['Category'] = restaurant_categories
#       4 total_restaurant_df.head()
#
# NameError: name 'restaurant_categories' is not defined

# %%
asian_categories = ['asianfusion','chinese','dumplings','japanese','korean','malaysian','mongloian','noodles','sushi','tawanese','thai','vietnamese']
total_restaurant_df.reset_index(inplace=True)
OCE_Asian_Restarants_total_count = total_restaurant_df.loc[total_restaurant_df['Category'].isin(asian_categories),:]
OCE_Asian_Restarants_total_count
# Out:
#      index  Oceanside,CA  Encinitas,CA  Carlsbad,CA  San Marcos,CA  \
# 6        6            25            47           36             35
# 40      40            51           100           66             73
# 53      53             0             0            0              0
# 93      93            46            94           68             67
# 97      97             6            19            7              7
# 104    104             4             0            1              1
# 121    121             8            20           10             14
# 164    164            52           108           78             77
# 175    175            25            48           36             39
# 185    185            19            50           26             29
#
#         Category
# 6    asianfusion
# 40       chinese
# 53     dumplings
# 93      japanese
# 97        korean
# 104    malaysian
# 121      noodles
# 164        sushi
# 175         thai
# 185   vietnamese

# %%
OCE_Asian_Restarants_total_count.plot(kind="bar")

# %%
restaurants_df = pd.DataFrame({
    "City": city_list,
    "Category": category_list,
    "Name": name_list,
    "Rating": rating_list,
    "Review Count": review_count_list,
    "Price":price_list
})
restaurants_df['Price']= pd.to_numeric(restaurants_df['Price'])
restaurants_df.head()
# Out:
#           City Category                Name  Rating  Review Count  Price
# 0  Carlsbad,CA  afghani          Baba Kabob     5.0            29      0
# 1  Carlsbad,CA  afghani   Pamir Kabob House     4.5           189      2
# 2  Carlsbad,CA  afghani      Ariana Cuisine     4.5           165      1
# 3  Carlsbad,CA  afghani  Ariana Kabob House     4.5           446      2
# 4  Carlsbad,CA  afghani          Kabul West     4.0            97      1

# %%
#Restaurant Rating - Oceanside
oceanside_df = restaurants_df.loc[restaurants_df["City"]=="Oceanside,CA",:]
oceanside_restaurant_rating = oceanside_df.groupby("Category")['Rating'].agg('mean')
oceanside_restaurant_rating = pd.DataFrame(oceanside_restaurant_rating)
#oceanside_restaurant_rating.head()

# %%
#Restaurant Rating - Carlsbad
carlsbad_df = restaurants_df.loc[restaurants_df["City"]=="Carlsbad,CA",:]
carlsbad_restaurant_rating = carlsbad_df.groupby("Category")['Rating'].agg('mean')
carlsbad_restaurant_rating_df = pd.DataFrame(carlsbad_restaurant_rating)
#carlsbad_restaurant_rating_df.head()

# %%
#Merged Files - Restaurant Rating Oceanside, Carlsbad, Encinitas
restaurant_rating = pd.merge(oceanside_restaurant_rating,carlsbad_restaurant_rating_df, on="Category", how="outer")
restaurant_rating_df = restaurant_rating.rename(columns={"Rating_x": "Avg Oceanside Restaurant Rating", "Rating_y":"Avg Carlsbad Restaurant Rating"})
#restaurant_rating_df.head()

# %%
#Restaurant Rating - Encinitas
encinitas_df = restaurants_df.loc[restaurants_df["City"]=="Encinitas,CA",:]
encinitas_restaurant_rating = encinitas_df.groupby("Category")['Rating'].agg('mean')
encinitas_restaurant_rating_df = pd.DataFrame(encinitas_restaurant_rating)
#encinitas_restaurant_rating_df.head()

# %%
#Merged Files - Restaurant Rating Oceanside, Carlsbad, Encinitas
OCE_restaurant_rating = pd.merge(restaurant_rating_df,encinitas_restaurant_rating_df, on="Category", how="outer")
OCE_restaurant_rating.rename(columns={"Rating": "Avg Encinitas Restaurant Rating"},inplace=True)
OCE_restaurant_rating.head()
# Out:
#            Avg Oceanside Restaurant Rating  Avg Carlsbad Restaurant Rating  \
# Category
# afghani                           4.000000                        4.076923
# african                           4.227273                        4.227273
# arabian                           4.375000                        4.357143
# argentine                         4.187500                        4.134615
# armenian                          4.500000                        4.750000
#
#            Avg Encinitas Restaurant Rating
# Category
# afghani                           4.500000
# african                           4.250000
# arabian                           4.250000
# argentine                         4.152174
# armenian                               NaN

# %%
asian_categories = ['asianfusion','chinese','dumplings','japanese','korean','malaysian','mongloian','noodles','sushi','tawanese','thai','vietnamese']
OCE_restaurant_rating.reset_index(inplace=True)
OCE_Asian_Restarants_rating_mean = OCE_restaurant_rating.loc[OCE_restaurant_rating['Category'].isin(asian_categories),:]
OCE_Asian_Restarants_rating_mean
# Out:
#         Category  Avg Oceanside Restaurant Rating  \
# 5    asianfusion                         3.680000
# 27       chinese                         3.300000
# 60      japanese                         3.793478
# 62        korean                         3.833333
# 66     malaysian                         4.250000
# 75       noodles                         3.500000
# 102        sushi                         3.850000
# 108         thai                         3.920000
# 114   vietnamese                         4.026316
#
#      Avg Carlsbad Restaurant Rating  Avg Encinitas Restaurant Rating
# 5                          3.722222                         3.712766
# 27                         3.560000                         3.740000
# 60                         3.890000                         4.020000
# 62                         3.857143                         3.868421
# 66                         4.000000                              NaN
# 75                         3.600000                         3.750000
# 102                        3.940000                         4.020000
# 108                        3.944444                         3.885417
# 114                        4.057692                         3.970000

# %%
OCE_Asian_Restarants_rating_mean.plot(kind="bar")

# %%
#Review Count

# %%
#Restaurant Review Count Per Category- Oceanside
oceanside_df = restaurants_df.loc[restaurants_df["City"]=="Oceanside,CA",:]
oceanside_restaurant_review_count = oceanside_df.groupby("Category")['Review Count'].agg('sum')
oceanside_restaurant_review_count_df = pd.DataFrame(oceanside_restaurant_review_count)
#oceanside_restaurant_review_count_df.head()

# %%
#Restaurant Review Count Per Category- Carlsbad
carlsbad_df = restaurants_df.loc[restaurants_df["City"]=="Carlsbad,CA",:]
carlsbad_restaurant_review_count = carlsbad_df.groupby("Category")['Review Count'].agg('sum')
carlsbad_restaurant_review_count_df = pd.DataFrame(carlsbad_restaurant_review_count)
#carlsbad_restaurant_review_count_df.head()

# %%
#Restaurant Review Count Per Category- Encinitas
encinitas_df = restaurants_df.loc[restaurants_df["City"]=="Encinitas,CA",:]
encinitas_restaurant_review_count = encinitas_df.groupby("Category")['Review Count'].agg('sum')
encinitas_restaurant_review_count_df = pd.DataFrame(encinitas_restaurant_review_count)
#encinitas_restaurant_review_count_df.head()

# %%
OC_review_count = pd.merge(oceanside_restaurant_review_count_df,carlsbad_restaurant_review_count_df, on="Category", how="outer")
OC_review_count.head()
OC_review_count_df = OC_review_count.rename(columns={"Review Count_x": "Oceanside Review Count",
                                 "Review Count_y": "Carlsbad Review Count"})
#OC_review_count_df.head()

# %%
OCE_review_count = pd.merge(OC_review_count_df,encinitas_restaurant_review_count_df, on="Category", how="outer")
OCE_review_count_df = OCE_review_count.rename(columns={"Review Count": "Encinitas Review Count"})
OCE_review_count_df.head()
# Out:
#            Oceanside Review Count  Carlsbad Review Count  \
# Category
# afghani                    3344.0                 3319.0
# african                    2803.0                 2803.0
# arabian                    1833.0                 1465.0
# argentine                  4177.0                 3992.0
# armenian                   2715.0                  489.0
#
#            Encinitas Review Count
# Category
# afghani                     926.0
# african                    2524.0
# arabian                     720.0
# argentine                  3109.0
# armenian                      NaN

# %%
asian_categories = ['asianfusion','chinese','dumplings','japanese','korean','malaysian','mongloian','noodles','sushi','tawanese','thai','vietnamese']
OCE_review_count_df.reset_index(inplace=True)
OCE_Asian_Restarants_review_count = OCE_review_count_df.loc[OCE_review_count_df['Category'].isin(asian_categories),:]
OCE_Asian_Restarants_review_count
# Out:
#      index     Category  Oceanside Review Count  Carlsbad Review Count  \
# 5        5  asianfusion                  5876.0                 8841.0
# 27      27      chinese                  5961.0                 9748.0
# 60      60     japanese                 13771.0                15489.0
# 62      62       korean                  1643.0                 2127.0
# 66      66    malaysian                  1486.0                  731.0
# 75      75      noodles                  2300.0                 2659.0
# 102    102        sushi                 17812.0                18857.0
# 108    108         thai                  7683.0                10785.0
# 114    114   vietnamese                  5433.0                 8197.0
#
#      Encinitas Review Count
# 5                   10970.0
# 27                  12118.0
# 60                  16365.0
# 62                   6223.0
# 66                      NaN
# 75                   5276.0
# 102                 18301.0
# 108                 15312.0
# 114                 15697.0

# %%
OCE_Asian_Restarants_review_count.plot(kind="bar")

# %%
#Price

# %%
#Restaurant Price Per Category- Oceanside
oceanside_df = restaurants_df.loc[restaurants_df["City"]=="Oceanside,CA",:]
oceanside_restaurant_price = oceanside_df.groupby("Category")['Price'].agg('mean')
oceanside_restaurant_price_df = pd.DataFrame(oceanside_restaurant_price)
#oceanside_restaurant_price_df.head()

# %%
#Restaurant Price Per Category- Carlsbad
carlsbad_df = restaurants_df.loc[restaurants_df["City"]=="Carlsbad,CA",:]
carlsbad_restaurant_price = carlsbad_df.groupby("Category")['Price'].agg('mean')
carlsbad_restaurant_price_df = pd.DataFrame(carlsbad_restaurant_price)
#carlsbad_restaurant_price_df.head()

# %%
#Restaurant Price Per Category- Encinitas
encinitas_df = restaurants_df.loc[restaurants_df["City"]=="Encinitas,CA",:]
encinitas_restaurant_price = encinitas_df.groupby("Category")['Price'].agg('mean')
encinitas_restaurant_price_df = pd.DataFrame(encinitas_restaurant_price)
#encinitas_restaurant_price_df.head()

# %%
#Price merge Oceanside and Carlsbad
OC_price_mean = pd.merge(oceanside_restaurant_price_df,carlsbad_restaurant_price_df, on="Category", how="outer")
OC_price_mean.head()
OC_price_mean_df = OC_price_mean.rename(columns={"Price_x": "Oceanside Mean Price Per Category",
                                 "Price_y": "Carlsbad Mean Price Per Category"})
#OC_price_mean_df.head()

# %%
#Price merge Oceanside, Carlsbad, Encinitas
OCE_price_mean = pd.merge(OC_price_mean_df,encinitas_restaurant_price_df, on="Category", how="outer")
OCE_price_mean_df = OCE_price_mean.rename(columns={"Price": "Encinitas Mean Price Per Category"})
OCE_price_mean_df.head()
# Out:
#            Oceanside Mean Price Per Category  \
# Category
# afghani                             1.285714
# african                             1.090909
# arabian                             1.000000
# argentine                           1.500000
# armenian                            1.000000
#
#            Carlsbad Mean Price Per Category  Encinitas Mean Price Per Category
# Category
# afghani                            1.307692                           1.200000
# african                            1.090909                           1.000000
# arabian                            0.857143                           0.750000
# argentine                          1.384615                           1.391304
# armenian                           0.500000                                NaN

# %%
asian_categories = ['asianfusion','chinese','dumplings','japanese','korean','malaysian','mongloian','noodles','sushi','tawanese','thai','vietnamese']
OCE_price_mean_df.reset_index(inplace=True)
OCE_Asian_Restarants_Price = OCE_price_mean_df.loc[OCE_price_mean_df['Category'].isin(asian_categories),:]
OCE_Asian_Restarants_Price
# Out:
#      level_0  index     Category  Oceanside Mean Price Per Category  \
# 5          5      5  asianfusion                           1.600000
# 27        27     27      chinese                           1.220000
# 60        60     60     japanese                           1.782609
# 62        62     62       korean                           2.000000
# 66        66     66    malaysian                           1.250000
# 75        75     75      noodles                           1.500000
# 102      102    102        sushi                           1.840000
# 108      108    108         thai                           1.800000
# 114      114    114   vietnamese                           1.052632
#
#      Carlsbad Mean Price Per Category  Encinitas Mean Price Per Category
# 5                            1.638889                           1.595745
# 27                           1.340000                           1.420000
# 60                           1.840000                           1.740000
# 62                           2.000000                           1.684211
# 66                           2.000000                                NaN
# 75                           1.500000                           1.250000
# 102                          1.920000                           1.980000
# 108                          1.722222                           1.750000
# 114                          1.115385                           1.060000

# %%
OCE_Asian_Restarants_Price.plot(kind='bar')
